# %% [markdown]
# # Modelo para decisão de risco de crédito

# %%
#install.packages("")

# %%
# Carregar pacotes
library(C50)
library(gmodels)

# %%
# Importar dados
credit <- read.csv("../data/credito.csv")

# %%
dim(credit)
head(credit)
# Out:
# [1] 1000   17
#   checking_balance months_loan_duration credit_history purpose
# 1 < 0 DM            6                   critical       furniture/appliances
# 2 1 - 200 DM       48                   good           furniture/appliances
# 3 unknown          12                   critical       education
# 4 < 0 DM           42                   good           furniture/appliances
# 5 < 0 DM           24                   poor           car
# 6 unknown          36                   good           education
#   amount savings_balance employment_duration percent_of_income
# 1 1169   unknown         > 7 years           4
# 2 5951   < 100 DM        1 - 4 years         2
# 3 2096   < 100 DM        4 - 7 years         2
# 4 7882   < 100 DM        4 - 7 years         2
# 5 4870   < 100 DM        1 - 4 years         3
# 6 9055   unknown         1 - 4 years         2
#   years_at_residence age other_credit housing existing_loans_count job
# 1 4                  67  none         own     2                    skilled
# 2 2                  22  none         own     1                    skilled
# 3 3                  49  none         own     1                    unskilled
# 4 4                  45  none         other   1                    skilled
# 5 4                  53  none         other   2                    skilled
# 6 4                  35  none         other   1                    unskilled
#   dependents phone default
# 1 1          yes   no
# 2 1          no    yes
# 3 2          no    no
# 4 2          no    no
# 5 2          no    yes
# 6 2          yes   no

# %% [markdown]
# # Explorar dados

# %%
# Info dos dados
str(credit)
# Out:
# 'data.frame':	1000 obs. of  17 variables:
#  $ checking_balance    : Factor w/ 4 levels "< 0 DM","> 200 DM",..: 1 3 4 1 1 4 4 3 4 3 ...
#  $ months_loan_duration: int  6 48 12 42 24 36 24 36 12 30 ...
#  $ credit_history      : Factor w/ 5 levels "critical","good",..: 1 2 1 2 4 2 2 2 2 1 ...
#  $ purpose             : Factor w/ 6 levels "business","car",..: 5 5 4 5 2 4 5 2 5 2 ...
#  $ amount              : int  1169 5951 2096 7882 4870 9055 2835 6948 3059 5234 ...
#  $ savings_balance     : Factor w/ 5 levels "< 100 DM","> 1000 DM",..: 5 1 1 1 1 5 4 1 2 1 ...
#  $ employment_duration : Factor w/ 5 levels "< 1 year","> 7 years",..: 2 3 4 4 3 3 2 3 4 5 ...
#  $ percent_of_income   : int  4 2 2 2 3 2 3 2 2 4 ...
#  $ years_at_residence  : int  4 2 3 4 4 4 4 2 4 2 ...
#  $ age                 : int  67 22 49 45 53 35 53 35 61 28 ...
#  $ other_credit        : Factor w/ 3 levels "bank","none",..: 2 2 2 2 2 2 2 2 2 2 ...
#  $ housing             : Factor w/ 3 levels "other","own",..: 2 2 2 1 1 1 2 3 2 2 ...
#  $ existing_loans_count: int  2 1 1 1 2 1 1 1 1 2 ...
#  $ job                 : Factor w/ 4 levels "management","skilled",..: 2 2 4 2 2 4 2 1 4 1 ...
#  $ dependents          : int  1 1 2 2 2 2 1 1 1 1 ...
#  $ phone               : Factor w/ 2 levels "no","yes": 2 1 1 1 1 2 1 2 1 1 ...
#  $ default             : Factor w/ 2 levels "no","yes": 1 2 1 1 2 1 1 1 1 2 ...

# %%
# Verificar atributos do cliente
table(credit$checking_balance)
table(credit$savings_balance)
# Out:
#     < 0 DM   > 200 DM 1 - 200 DM    unknown
#        274         63        269        394
#      < 100 DM     > 1000 DM  100 - 500 DM 500 - 1000 DM       unknown
#           603            48           103            63           183

# %%
# Características do crédito
summary(credit$months_loan_duration)
summary(credit$amount)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     4.0    12.0    18.0    20.9    24.0    72.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     250    1366    2320    3271    3972   18424

# %%
# Variável target
table(credit$default)
# Out:
#  no yes
# 700 300

# %% [markdown]
# # Construir dados de treino e teste

# %%
# Construir indice para separa dados
train_sample <- sample(1000, 900)

# %%
# Split dos dataframes
credit_train <- credit[train_sample, ]
credit_test  <- credit[-train_sample, ]

# %%
# Verificar proporção da variável target
print("Treino")
prop.table(table(credit_train$default))
print("Teste")
prop.table(table(credit_test$default))
# Out:
# [1] "Treino"
#        no       yes
# 0.7033333 0.2966667
# [1] "Teste"
#   no  yes
# 0.67 0.33

# %% [markdown]
# # Construir modelo

# %%
credit_model <- C5.0(credit_train[-17], credit_train$default)
credit_model
# Out:
# Call:
# C5.0.default(x = credit_train[-17], y = credit_train$default)
#
# Classification Tree
# Number of samples: 900
# Number of predictors: 16
#
# Tree size: 56
#
# Non-standard options: attempt to group attributes

# %%
# Info do modelo
summary(credit_model)
# Out:
# Call:
# C5.0.default(x = credit_train[-17], y = credit_train$default)
#
#
# C5.0 [Release 2.07 GPL Edition]  	Wed Jul 22 17:22:49 2020
# -------------------------------
#
# Class specified by attribute `outcome'
#
# Read 900 cases (17 attributes) from undefined.data
#
# Decision tree:
#
# checking_balance = unknown: no (358/45)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...months_loan_duration > 30:
#     :...employment_duration = unemployed: no (8)
#     :   employment_duration in {< 1 year,> 7 years,1 - 4 years,4 - 7 years}:
#     :   :...checking_balance = < 0 DM: yes (39/6)
#     :       checking_balance = > 200 DM: no (6/1)
#     :       checking_balance = 1 - 200 DM:
#     :       :...savings_balance in {500 - 1000 DM,unknown}: no (8/1)
#     :           savings_balance in {< 100 DM,> 1000 DM,100 - 500 DM}:
#     :           :...months_loan_duration > 42: yes (16)
#     :               months_loan_duration <= 42:
#     :               :...phone = no: no (9/3)
#     :                   phone = yes:
#     :                   :...age > 38: yes (6)
#     :                       age <= 38:
#     :                       :...other_credit = bank: no (0)
#     :                           other_credit = store: yes (1)
#     :                           other_credit = none:
#     :                           :...age <= 29: yes (2)
#     :                               age > 29: no (4)
#     months_loan_duration <= 30:
#     :...credit_history in {perfect,very good}: yes (44/16)
#         credit_history in {critical,good,poor}:
#         :...months_loan_duration <= 11: no (87/14)
#             months_loan_duration > 11:
#             :...amount <= 1381:
#                 :...other_credit = store: yes (4)
#                 :   other_credit = bank:
#                 :   :...purpose in {business,car,car0,renovations}: yes (8)
#                 :   :   purpose = education: no (1)
#                 :   :   purpose = furniture/appliances:
#                 :   :   :...job in {management,skilled,unemployed}: yes (3)
#                 :   :       job = unskilled: no (2)
#                 :   other_credit = none:
#                 :   :...checking_balance in {> 200 DM,
#                 :       :                    1 - 200 DM}: no (35/10)
#                 :       checking_balance = < 0 DM:
#                 :       :...purpose = business: no (1)
#                 :           purpose in {car,car0,education,
#                 :           :           renovations}: yes (21/2)
#                 :           purpose = furniture/appliances:
#                 :           :...savings_balance in {> 1000 DM,
#                 :               :                   500 - 1000 DM}: no (0)
#                 :               savings_balance = 100 - 500 DM: yes (3)
#                 :               savings_balance in {< 100 DM,unknown}:
#                 :               :...amount <= 1113: no (7)
#                 :                   amount > 1113: yes (4/1)
#                 amount > 1381:
#                 :...savings_balance in {> 1000 DM,unknown}: no (46/7)
#                     savings_balance = 500 - 1000 DM:
#                     :...months_loan_duration <= 21: no (7)
#                     :   months_loan_duration > 21: yes (3/1)
#                     savings_balance = 100 - 500 DM:
#                     :...housing = other: no (1)
#                     :   housing = own:
#                     :   :...purpose in {business,car,car0,education,
#                     :   :   :           renovations}: no (10)
#                     :   :   purpose = furniture/appliances: yes (3/1)
#                     :   housing = rent:
#                     :   :...credit_history in {critical,poor}: no (3)
#                     :       credit_history = good: yes (4)
#                     savings_balance = < 100 DM:
#                     :...months_loan_duration <= 15: no (50/10)
#                         months_loan_duration > 15:
#                         :...employment_duration = < 1 year:
#                             :...job in {management,skilled,
#                             :   :       unemployed}: no (15/5)
#                             :   job = unskilled: yes (5/1)
#                             employment_duration = unemployed:
#                             :...phone = no: yes (2)
#                             :   phone = yes: no (7/2)
#                             employment_duration = > 7 years:
#                             :...housing in {other,own}: no (20/3)
#                             :   housing = rent:
#                             :   :...amount <= 2503: no (2)
#                             :       amount > 2503: yes (3)
#                             employment_duration = 4 - 7 years:
#                             :...months_loan_duration <= 22: no (6)
#                             :   months_loan_duration > 22:
#                             :   :...other_credit = store: yes (0)
#                             :       other_credit = bank: no (1)
#                             :       other_credit = none:
#                             :       :...job = management: no (1)
#                             :           job in {skilled,unemployed,
#                             :                   unskilled}: yes (4)
#                             employment_duration = 1 - 4 years:
#                             :...existing_loans_count > 1:
#                                 :...checking_balance in {< 0 DM,
#                                 :   :                    > 200 DM}: yes (6)
#                                 :   checking_balance = 1 - 200 DM:
#                                 :   :...months_loan_duration <= 22: no (2)
#                                 :       months_loan_duration > 22: yes (2)
#                                 existing_loans_count <= 1:
#                                 :...amount <= 2748: yes (6)
#                                     amount > 2748:
#                                     :...years_at_residence > 3: no (5)
#                                         years_at_residence <= 3:
#                                         :...housing = other: yes (0)
#                                             housing = rent: no (2)
#                                             housing = own: [S1]
#
# SubTree [S1]
#
# other_credit in {bank,none}: yes (6/1)
# other_credit = store: no (1)
#
#
# Evaluation on training data (900 cases):
#
# 	    Decision Tree
# 	  ----------------
# 	  Size      Errors
#
# 	    52  130(14.4%)   <<
#
#
# 	   (a)   (b)    <-classified as
# 	  ----  ----
# 	   604    29    (a): class no
# 	   101   166    (b): class yes
#
#
# 	Attribute usage:
#
# 	100.00%	checking_balance
# 	 60.22%	months_loan_duration
# 	 49.22%	credit_history
# 	 34.67%	amount
# 	 31.44%	savings_balance
# 	 21.67%	employment_duration
# 	 12.11%	other_credit
# 	  7.00%	purpose
# 	  6.11%	housing
# 	  3.44%	phone
# 	  3.33%	existing_loans_count
# 	  3.33%	job
# 	  1.56%	years_at_residence
# 	  1.44%	age
#
#
# Time: 0.0 secs

# %% [markdown]
# # Avaliar performance

# %%
credit_pred <- predict(credit_model, credit_test)
credit_pred
# Out:
#   [1] no  no  no  no  no  no  yes no  no  no  no  yes yes no  no  no  yes yes
#  [19] yes no  yes no  yes yes no  yes yes no  no  yes no  no  no  no  no  no
#  [37] yes no  yes no  yes no  no  no  no  yes no  no  no  yes yes yes no  no
#  [55] yes yes no  no  no  no  no  yes no  no  no  no  no  yes no  yes no  yes
#  [73] no  no  no  no  yes no  no  no  no  no  yes no  yes no  no  yes no  no
#  [91] no  yes yes no  no  yes no  no  yes no
# Levels: no yes

# %%
# Confusion matrix
CrossTable(credit_test$default, 
           credit_pred,
           prop.chisq = FALSE, 
           prop.c = FALSE, 
           prop.r = FALSE,
           dnn = c('Observado', 'Previsto'))
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  100
#
#
#              | Previsto
#    Observado |        no |       yes | Row Total |
# -------------|-----------|-----------|-----------|
#           no |        57 |        10 |        67 |
#              |     0.570 |     0.100 |           |
# -------------|-----------|-----------|-----------|
#          yes |        10 |        23 |        33 |
#              |     0.100 |     0.230 |           |
# -------------|-----------|-----------|-----------|
# Column Total |        67 |        33 |       100 |
# -------------|-----------|-----------|-----------|

# %% [markdown]
# # Melhorar performance

# %%
# Aumentando a precisão com 10 tentativas
credit_boost10 <- C5.0(credit_train[-17], credit_train$default, trials = 10)
credit_boost10
# Out:
# Call:
# C5.0.default(x = credit_train[-17], y = credit_train$default, trials = 10)
#
# Classification Tree
# Number of samples: 900
# Number of predictors: 16
#
# Number of boosting iterations: 10
# Average tree size: 45.3
#
# Non-standard options: attempt to group attributes

# %%
summary(credit_boost10)
# Out:
# Call:
# C5.0.default(x = credit_train[-17], y = credit_train$default, trials = 10)
#
#
# C5.0 [Release 2.07 GPL Edition]  	Wed Jul 22 17:26:51 2020
# -------------------------------
#
# Class specified by attribute `outcome'
#
# Read 900 cases (17 attributes) from undefined.data
#
# -----  Trial 0:  -----
#
# Decision tree:
#
# checking_balance = unknown: no (358/45)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...months_loan_duration > 30:
#     :...employment_duration = unemployed: no (8)
#     :   employment_duration in {< 1 year,> 7 years,1 - 4 years,4 - 7 years}:
#     :   :...checking_balance = < 0 DM: yes (39/6)
#     :       checking_balance = > 200 DM: no (6/1)
#     :       checking_balance = 1 - 200 DM:
#     :       :...savings_balance in {500 - 1000 DM,unknown}: no (8/1)
#     :           savings_balance in {< 100 DM,> 1000 DM,100 - 500 DM}:
#     :           :...months_loan_duration > 42: yes (16)
#     :               months_loan_duration <= 42:
#     :               :...phone = no: no (9/3)
#     :                   phone = yes:
#     :                   :...age > 38: yes (6)
#     :                       age <= 38:
#     :                       :...other_credit = bank: no (0)
#     :                           other_credit = store: yes (1)
#     :                           other_credit = none:
#     :                           :...age <= 29: yes (2)
#     :                               age > 29: no (4)
#     months_loan_duration <= 30:
#     :...credit_history in {perfect,very good}: yes (44/16)
#         credit_history in {critical,good,poor}:
#         :...months_loan_duration <= 11: no (87/14)
#             months_loan_duration > 11:
#             :...amount <= 1381:
#                 :...other_credit = store: yes (4)
#                 :   other_credit = bank:
#                 :   :...purpose in {business,car,car0,renovations}: yes (8)
#                 :   :   purpose = education: no (1)
#                 :   :   purpose = furniture/appliances:
#                 :   :   :...job in {management,skilled,unemployed}: yes (3)
#                 :   :       job = unskilled: no (2)
#                 :   other_credit = none:
#                 :   :...checking_balance in {> 200 DM,
#                 :       :                    1 - 200 DM}: no (35/10)
#                 :       checking_balance = < 0 DM:
#                 :       :...purpose = business: no (1)
#                 :           purpose in {car,car0,education,
#                 :           :           renovations}: yes (21/2)
#                 :           purpose = furniture/appliances:
#                 :           :...savings_balance in {> 1000 DM,
#                 :               :                   500 - 1000 DM}: no (0)
#                 :               savings_balance = 100 - 500 DM: yes (3)
#                 :               savings_balance in {< 100 DM,unknown}:
#                 :               :...amount <= 1113: no (7)
#                 :                   amount > 1113: yes (4/1)
#                 amount > 1381:
#                 :...savings_balance in {> 1000 DM,unknown}: no (46/7)
#                     savings_balance = 500 - 1000 DM:
#                     :...months_loan_duration <= 21: no (7)
#                     :   months_loan_duration > 21: yes (3/1)
#                     savings_balance = 100 - 500 DM:
#                     :...housing = other: no (1)
#                     :   housing = own:
#                     :   :...purpose in {business,car,car0,education,
#                     :   :   :           renovations}: no (10)
#                     :   :   purpose = furniture/appliances: yes (3/1)
#                     :   housing = rent:
#                     :   :...credit_history in {critical,poor}: no (3)
#                     :       credit_history = good: yes (4)
#                     savings_balance = < 100 DM:
#                     :...months_loan_duration <= 15: no (50/10)
#                         months_loan_duration > 15:
#                         :...employment_duration = < 1 year:
#                             :...job in {management,skilled,
#                             :   :       unemployed}: no (15/5)
#                             :   job = unskilled: yes (5/1)
#                             employment_duration = unemployed:
#                             :...phone = no: yes (2)
#                             :   phone = yes: no (7/2)
#                             employment_duration = > 7 years:
#                             :...housing in {other,own}: no (20/3)
#                             :   housing = rent:
#                             :   :...amount <= 2503: no (2)
#                             :       amount > 2503: yes (3)
#                             employment_duration = 4 - 7 years:
#                             :...months_loan_duration <= 22: no (6)
#                             :   months_loan_duration > 22:
#                             :   :...other_credit = store: yes (0)
#                             :       other_credit = bank: no (1)
#                             :       other_credit = none:
#                             :       :...job = management: no (1)
#                             :           job in {skilled,unemployed,
#                             :                   unskilled}: yes (4)
#                             employment_duration = 1 - 4 years:
#                             :...existing_loans_count > 1:
#                                 :...checking_balance in {< 0 DM,
#                                 :   :                    > 200 DM}: yes (6)
#                                 :   checking_balance = 1 - 200 DM:
#                                 :   :...months_loan_duration <= 22: no (2)
#                                 :       months_loan_duration > 22: yes (2)
#                                 existing_loans_count <= 1:
#                                 :...amount <= 2748: yes (6)
#                                     amount > 2748:
#                                     :...years_at_residence > 3: no (5)
#                                         years_at_residence <= 3:
#                                         :...housing = other: yes (0)
#                                             housing = rent: no (2)
#                                             housing = own: [S1]
#
# SubTree [S1]
#
# other_credit in {bank,none}: yes (6/1)
# other_credit = store: no (1)
#
# -----  Trial 1:  -----
#
# Decision tree:
#
# credit_history = critical:
# :...other_credit in {bank,store}:
# :   :...age <= 45: yes (32.4/11.9)
# :   :   age > 45: no (7.1)
# :   other_credit = none:
# :   :...checking_balance = unknown: no (104.9/6.7)
# :       checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :       :...purpose in {business,car0,furniture/appliances,
# :           :           renovations}: no (49/17.5)
# :           purpose = education: yes (9.9/2.4)
# :           purpose = car:
# :           :...existing_loans_count <= 1: no (7.1)
# :               existing_loans_count > 1:
# :               :...age <= 29: yes (8.4/1.6)
# :                   age > 29: no (26.6/3.8)
# credit_history in {good,perfect,poor,very good}:
# :...employment_duration in {< 1 year,unemployed}:
#     :...percent_of_income > 2: yes (116.8/41.7)
#     :   percent_of_income <= 2:
#     :   :...existing_loans_count <= 1: no (53.5/19.1)
#     :       existing_loans_count > 1: yes (20.5/7)
#     employment_duration = 4 - 7 years:
#     :...checking_balance = < 0 DM: yes (26.5/13)
#     :   checking_balance in {> 200 DM,1 - 200 DM,unknown}:
#     :   :...housing = other: yes (2.4)
#     :       housing in {own,rent}: no (62.9/9.2)
#     employment_duration in {> 7 years,1 - 4 years}:
#     :...months_loan_duration <= 8: no (19.8/0.8)
#         months_loan_duration > 8:
#         :...housing = other:
#             :...amount > 10722: yes (4.6)
#             :   amount <= 10722:
#             :   :...savings_balance in {500 - 1000 DM,unknown}: no (11.1/0.8)
#             :       savings_balance in {< 100 DM,> 1000 DM,100 - 500 DM}:
#             :       :...years_at_residence <= 3: no (4.8/0.8)
#             :           years_at_residence > 3: yes (25.9/5.4)
#             housing = rent:
#             :...credit_history = perfect: yes (3.2)
#             :   credit_history = poor: no (4)
#             :   credit_history in {good,very good}:
#             :   :...checking_balance = > 200 DM: no (4.6)
#             :       checking_balance in {< 0 DM,1 - 200 DM,unknown}:
#             :       :...existing_loans_count > 1: yes (8.4/0.8)
#             :           existing_loans_count <= 1:
#             :           :...months_loan_duration <= 24: no (31.3/11.6)
#             :               months_loan_duration > 24: yes (6.2/0.8)
#             housing = own:
#             :...job = unemployed: no (0)
#                 job = management:
#                 :...phone = no: no (4.6)
#                 :   phone = yes: yes (30.7/10.3)
#                 job = skilled:
#                 :...years_at_residence > 3:
#                 :   :...months_loan_duration <= 20: no (17.9)
#                 :   :   months_loan_duration > 20:
#                 :   :   :...percent_of_income <= 2: yes (12.1/3.2)
#                 :   :       percent_of_income > 2: no (21/4.6)
#                 :   years_at_residence <= 3:
#                 :   :...existing_loans_count > 1: no (22.2/7.5)
#                 :       existing_loans_count <= 1:
#                 :       :...credit_history in {perfect,poor}: yes (4.6)
#                 :           credit_history = very good: no (3.8/0.8)
#                 :           credit_history = good:
#                 :           :...checking_balance in {< 0 DM,
#                 :               :                    1 - 200 DM}: yes (45.4/15.7)
#                 :               checking_balance in {> 200 DM,
#                 :                                    unknown}: no (24.1/7.5)
#                 job = unskilled:
#                 :...percent_of_income <= 2: no (17.1/1.6)
#                     percent_of_income > 2:
#                     :...credit_history in {perfect,very good}: no (6)
#                         credit_history in {good,poor}:
#                         :...dependents > 1: yes (6/0.8)
#                             dependents <= 1:
#                             :...existing_loans_count > 1: no (4)
#                                 existing_loans_count <= 1: [S1]
#
# SubTree [S1]
#
# employment_duration = > 7 years: no (4.8/0.8)
# employment_duration = 1 - 4 years: yes (23.7/9.4)
#
# -----  Trial 2:  -----
#
# Decision tree:
#
# checking_balance = unknown:
# :...other_credit in {bank,store}:
# :   :...purpose in {car0,renovations}: yes (0)
# :   :   purpose = furniture/appliances: no (28/7.4)
# :   :   purpose in {business,car,education}:
# :   :   :...months_loan_duration <= 9: no (2.7)
# :   :       months_loan_duration > 9: yes (40.8/11.2)
# :   other_credit = none:
# :   :...age > 32: no (130.3/13)
# :       age <= 32:
# :       :...amount > 6458: yes (13.7/2.6)
# :           amount <= 6458:
# :           :...age <= 22: yes (16.4/5.3)
# :               age > 22:
# :               :...years_at_residence <= 3: no (67.2/11.1)
# :                   years_at_residence > 3:
# :                   :...phone = no: yes (17.7/6.6)
# :                       phone = yes: no (7.9)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...savings_balance in {> 1000 DM,500 - 1000 DM}: no (48.9/13.7)
#     savings_balance = 100 - 500 DM:
#     :...phone = no: yes (32.7/13.1)
#     :   phone = yes: no (17/5.9)
#     savings_balance = unknown:
#     :...credit_history in {critical,perfect,poor,very good}: no (31.8/4.1)
#     :   credit_history = good:
#     :   :...job = unskilled: no (6.5)
#     :       job in {management,skilled,unemployed}:
#     :       :...checking_balance = < 0 DM: yes (16.6/4)
#     :           checking_balance = > 200 DM: no (2)
#     :           checking_balance = 1 - 200 DM:
#     :           :...amount > 9857: yes (4.6)
#     :               amount <= 9857:
#     :               :...months_loan_duration <= 18: yes (17.5/7.3)
#     :                   months_loan_duration > 18: no (9.3)
#     savings_balance = < 100 DM:
#     :...months_loan_duration > 42: yes (23.2/4.6)
#         months_loan_duration <= 42:
#         :...housing = rent: yes (73.1/30.3)
#             housing in {other,own}:
#             :...percent_of_income <= 1:
#                 :...amount <= 1136: yes (3.8/0.7)
#                 :   amount > 1136: no (22.5/1.3)
#                 percent_of_income > 1:
#                 :...credit_history = perfect: no (12.3/2.6)
#                     credit_history in {poor,very good}: yes (35.6/11.1)
#                     credit_history in {critical,good}:
#                     :...months_loan_duration <= 8: no (16.4/1.9)
#                         months_loan_duration > 8:
#                         :...years_at_residence > 3: no (64.3/21.1)
#                             years_at_residence <= 3:
#                             :...years_at_residence <= 1:
#                                 :...other_credit = bank: no (9.4)
#                                 :   other_credit in {none,store}:
#                                 :   :...phone = yes: no (6/0.7)
#                                 :       phone = no:
#                                 :       :...age <= 26: no (10.1/1.3)
#                                 :           age > 26: yes (14.7/4.7)
#                                 years_at_residence > 1:
#                                 :...job = management: yes (13.5/6.5)
#                                     job = unemployed: no (1.3)
#                                     job = unskilled: [S1]
#                                     job = skilled:
#                                     :...dependents > 1: yes (5.1)
#                                         dependents <= 1: [S2]
#
# SubTree [S1]
#
# checking_balance in {< 0 DM,1 - 200 DM}: no (21.1/7.7)
# checking_balance = > 200 DM: yes (4.6)
#
# SubTree [S2]
#
# months_loan_duration > 16: yes (26.8/4)
# months_loan_duration <= 16:
# :...phone = no: no (19.9/7.3)
#     phone = yes: yes (4.4/0.7)
#
# -----  Trial 3:  -----
#
# Decision tree:
#
# checking_balance in {> 200 DM,unknown}:
# :...employment_duration in {> 7 years,4 - 7 years}: no (156.1/31)
# :   employment_duration in {< 1 year,1 - 4 years,unemployed}:
# :   :...amount > 3913:
# :       :...dependents <= 1: yes (51.7/15)
# :       :   dependents > 1: no (8.6/2.3)
# :       amount <= 3913:
# :       :...percent_of_income <= 1: no (16.1)
# :           percent_of_income > 1:
# :           :...age > 43: no (15.5)
# :               age <= 43:
# :               :...savings_balance in {> 1000 DM,100 - 500 DM,
# :                   :                   unknown}: no (33.5/8.3)
# :                   savings_balance = 500 - 1000 DM: yes (11.3/4.1)
# :                   savings_balance = < 100 DM:
# :                   :...job = management: no (11.3/5.2)
# :                       job in {unemployed,unskilled}: yes (18.2/6.9)
# :                       job = skilled:
# :                       :...age <= 22: yes (4.6)
# :                           age > 22: no (44.6/8.1)
# checking_balance in {< 0 DM,1 - 200 DM}:
# :...savings_balance in {> 1000 DM,500 - 1000 DM,unknown}: no (115.5/40.5)
#     savings_balance = 100 - 500 DM:
#     :...job in {management,unskilled}: yes (19/7.2)
#     :   job in {skilled,unemployed}: no (34.6/13.5)
#     savings_balance = < 100 DM:
#     :...dependents > 1:
#         :...other_credit = bank: yes (6.3/1.6)
#         :   other_credit = store: no (1.7/0.5)
#         :   other_credit = none:
#         :   :...age <= 50: no (41.8/11)
#         :       age > 50: yes (3)
#         dependents <= 1:
#         :...years_at_residence <= 1:
#             :...job in {management,unskilled}: no (22/2.1)
#             :   job = unemployed: yes (1.1)
#             :   job = skilled:
#             :   :...housing = other: no (2.2/1.1)
#             :       housing = rent: yes (7.3/1.9)
#             :       housing = own:
#             :       :...months_loan_duration <= 18: no (19.3/3.5)
#             :           months_loan_duration > 18: yes (12.5/3.2)
#             years_at_residence > 1:
#             :...months_loan_duration > 42: yes (12.6)
#                 months_loan_duration <= 42:
#                 :...purpose in {business,education}: yes (22.3/7.2)
#                     purpose in {car0,renovations}: no (5.2/0.5)
#                     purpose = car:
#                     :...percent_of_income > 2: yes (54.3/17.3)
#                     :   percent_of_income <= 2:
#                     :   :...job in {management,skilled,
#                     :       :       unemployed}: no (23.6/5.1)
#                     :       job = unskilled: yes (3)
#                     purpose = furniture/appliances:
#                     :...checking_balance = 1 - 200 DM:
#                         :...years_at_residence <= 2: yes (18.2/5.5)
#                         :   years_at_residence > 2: no (28.9/4.4)
#                         checking_balance = < 0 DM:
#                         :...amount > 4870: yes (4.6)
#                             amount <= 4870:
#                             :...job in {management,unemployed,
#                                 :       unskilled}: no (30.8/10.2)
#                                 job = skilled:
#                                 :...other_credit in {bank,store}: yes (5.5)
#                                     other_credit = none:
#                                     :...phone = yes: yes (3.5)
#                                         phone = no:
#                                         :...age <= 59: no (25/9.1)
#                                             age > 59: yes (4.6)
#
# -----  Trial 4:  -----
#
# Decision tree:
#
# checking_balance = unknown:
# :...other_credit = store: no (20.2/8.3)
# :   other_credit = bank:
# :   :...years_at_residence > 2: no (28.2/9.8)
# :   :   years_at_residence <= 2:
# :   :   :...percent_of_income <= 1: no (2.9)
# :   :       percent_of_income > 1: yes (21.4/4.2)
# :   other_credit = none:
# :   :...credit_history in {perfect,very good}: no (2.5)
# :       credit_history = good:
# :       :...existing_loans_count <= 1: no (98.7/23.3)
# :       :   existing_loans_count > 1: yes (17/6.2)
# :       credit_history = poor:
# :       :...percent_of_income <= 3: no (11.1/1.3)
# :       :   percent_of_income > 3: yes (20.6/5.4)
# :       credit_history = critical:
# :       :...age > 30: no (45.8)
# :           age <= 30:
# :           :...purpose in {business,car,car0,furniture/appliances,
# :               :           renovations}: no (23/4.8)
# :               purpose = education: yes (3.9)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...purpose = car0: no (10.1/4.4)
#     purpose = renovations: yes (14.5/6.9)
#     purpose = business:
#     :...age <= 49: no (47.1/10.7)
#     :   age > 49: yes (6.5)
#     purpose = education:
#     :...dependents <= 1: no (28.4/12.5)
#     :   dependents > 1: yes (9.4/1)
#     purpose = car:
#     :...credit_history in {critical,poor}: no (65.8/22.5)
#     :   credit_history in {perfect,very good}: yes (16.2/5.6)
#     :   credit_history = good:
#     :   :...amount > 11054: yes (8.6)
#     :       amount <= 11054:
#     :       :...employment_duration = unemployed: no (6.4)
#     :           employment_duration in {< 1 year,> 7 years,1 - 4 years,
#     :           :                       4 - 7 years}:
#     :           :...other_credit in {bank,store}: yes (11.5/3.1)
#     :               other_credit = none:
#     :               :...age > 43: yes (8.9/0.5)
#     :                   age <= 43:
#     :                   :...months_loan_duration > 40: no (7/2.1)
#     :                       months_loan_duration <= 40:
#     :                       :...age > 38: no (5)
#     :                           age <= 38:
#     :                           :...checking_balance = < 0 DM: yes (37.1/11)
#     :                               checking_balance in {> 200 DM,
#     :                                                    1 - 200 DM}: no (30.2/11.7)
#     purpose = furniture/appliances:
#     :...months_loan_duration <= 11: no (44.8/12.7)
#         months_loan_duration > 11:
#         :...months_loan_duration > 42: yes (13/1.4)
#             months_loan_duration <= 42:
#             :...savings_balance = > 1000 DM: no (6.2)
#                 savings_balance in {< 100 DM,100 - 500 DM,500 - 1000 DM,
#                 :                   unknown}:
#                 :...years_at_residence <= 1:
#                     :...percent_of_income <= 2: yes (20.6/7.6)
#                     :   percent_of_income > 2:
#                     :   :...credit_history in {critical,good,
#                     :       :                  poor}: no (21.7/1)
#                     :       credit_history in {perfect,
#                     :                          very good}: yes (2.7)
#                     years_at_residence > 1:
#                     :...job in {management,unemployed}: no (24.5/8.7)
#                         job = unskilled:
#                         :...percent_of_income <= 1: no (3)
#                         :   percent_of_income > 1:
#                         :   :...savings_balance in {< 100 DM,100 - 500 DM,
#                         :       :                   500 - 1000 DM}: yes (39.1/13.6)
#                         :       savings_balance = unknown: no (4.9)
#                         job = skilled:
#                         :...employment_duration in {< 1 year,
#                             :                       unemployed}: yes (23.4/6.5)
#                             employment_duration = 4 - 7 years: no (16.4/7)
#                             employment_duration = > 7 years:
#                             :...other_credit = bank: yes (3.9)
#                             :   other_credit in {none,store}: no (21.9/8.9)
#                             employment_duration = 1 - 4 years:
#                             :...months_loan_duration <= 13: no (4.8/0.5)
#                                 months_loan_duration > 13:
#                                 :...credit_history in {critical,good,
#                                     :                  poor}: yes (35.2/6.3)
#                                     credit_history in {perfect,
#                                                        very good}: no (6/0.9)
#
# -----  Trial 5:  -----
#
# Decision tree:
#
# checking_balance = unknown:
# :...other_credit in {bank,store}:
# :   :...employment_duration in {< 1 year,4 - 7 years}: no (15.6/3.9)
# :   :   employment_duration = unemployed: yes (4.8)
# :   :   employment_duration = > 7 years:
# :   :   :...age <= 41: yes (15.6/3.4)
# :   :   :   age > 41: no (8.4)
# :   :   employment_duration = 1 - 4 years:
# :   :   :...years_at_residence <= 1: no (2.8)
# :   :       years_at_residence > 1: yes (26.1/9.5)
# :   other_credit = none:
# :   :...credit_history in {good,perfect,very good}: no (115.2/38.4)
# :       credit_history = critical:
# :       :...amount <= 11816: no (59.3/5.8)
# :       :   amount > 11816: yes (3.4)
# :       credit_history = poor:
# :       :...dependents > 1: yes (6/1)
# :           dependents <= 1:
# :           :...age <= 29: yes (14.6/5.1)
# :               age > 29: no (11.9)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...years_at_residence <= 1:
#     :...housing = rent: yes (14.3/3.4)
#     :   housing in {other,own}:
#     :   :...employment_duration in {< 1 year,> 7 years,1 - 4 years,
#     :       :                       4 - 7 years}: no (74.6/21)
#     :       employment_duration = unemployed: yes (6.2/1.3)
#     years_at_residence > 1:
#     :...months_loan_duration > 26:
#         :...employment_duration in {< 1 year,> 7 years,1 - 4 years,
#         :   :                       4 - 7 years}: yes (116/35.9)
#         :   employment_duration = unemployed: no (11.1/2.9)
#         months_loan_duration <= 26:
#         :...percent_of_income <= 2:
#             :...savings_balance in {> 1000 DM,500 - 1000 DM}: no (8.7)
#             :   savings_balance in {< 100 DM,100 - 500 DM,unknown}:
#             :   :...job in {management,unemployed}: yes (18.3/4)
#             :       job in {skilled,unskilled}: no (101.7/35.4)
#             percent_of_income > 2:
#             :...job = unemployed: no (1.7)
#                 job = management:
#                 :...other_credit = bank: no (4.4)
#                 :   other_credit in {none,store}:
#                 :   :...age <= 32: no (9/1.1)
#                 :       age > 32:
#                 :       :...credit_history = critical: no (4)
#                 :           credit_history in {good,perfect,poor,
#                 :                              very good}: yes (21.8/4.3)
#                 job = skilled:
#                 :...years_at_residence <= 3:
#                 :   :...dependents > 1: yes (9.7/0.4)
#                 :   :   dependents <= 1:
#                 :   :   :...months_loan_duration <= 11: no (10.6/1.8)
#                 :   :       months_loan_duration > 11: yes (59.8/14.2)
#                 :   years_at_residence > 3:
#                 :   :...housing in {other,rent}: yes (36.6/14)
#                 :       housing = own:
#                 :       :...employment_duration = < 1 year: yes (9.1/1.9)
#                 :           employment_duration in {> 7 years,1 - 4 years,
#                 :                                   4 - 7 years,
#                 :                                   unemployed}: no (26.2/2.6)
#                 job = unskilled:
#                 :...purpose in {business,car0,renovations}: no (7.7/0.4)
#                     purpose = education: yes (2.4)
#                     purpose = car:
#                     :...months_loan_duration <= 21: no (14.6/3.8)
#                     :   months_loan_duration > 21: yes (9.5)
#                     purpose = furniture/appliances:
#                     :...existing_loans_count > 1: no (6)
#                         existing_loans_count <= 1:
#                         :...phone = yes: yes (4.3)
#                             phone = no:
#                             :...amount <= 776: yes (9.2/2.8)
#                                 amount > 776: no (19/3)
#
# -----  Trial 6:  -----
#
# Decision tree:
#
# credit_history = very good:
# :...age <= 23: no (5.3)
# :   age > 23: yes (46.8/16.7)
# credit_history = perfect:
# :...other_credit = bank: no (10.8/2.7)
# :   other_credit = store: yes (4.3)
# :   other_credit = none:
# :   :...years_at_residence <= 2: no (13.1/5.4)
# :       years_at_residence > 2: yes (11.3/0.3)
# credit_history = poor:
# :...checking_balance = < 0 DM: yes (10.3/0.6)
# :   checking_balance in {> 200 DM,1 - 200 DM,unknown}:
# :   :...savings_balance in {> 1000 DM,500 - 1000 DM}: yes (8/1.5)
# :       savings_balance in {100 - 500 DM,unknown}: no (25.1/3)
# :       savings_balance = < 100 DM:
# :       :...housing in {other,rent}: no (6.2/0.8)
# :           housing = own:
# :           :...existing_loans_count <= 1: yes (15.9/5.1)
# :               existing_loans_count > 1:
# :               :...dependents <= 1: no (23.2/5.4)
# :                   dependents > 1: yes (2.1)
# credit_history = critical:
# :...other_credit = store: no (10/3.7)
# :   other_credit = bank:
# :   :...age > 45: no (6.3)
# :   :   age <= 45:
# :   :   :...dependents > 1: yes (7.9)
# :   :       dependents <= 1:
# :   :       :...housing in {other,own}: no (19/7.1)
# :   :           housing = rent: yes (6.9)
# :   other_credit = none:
# :   :...purpose in {business,car0}: no (4.9)
# :       purpose = education: yes (15.8/5.3)
# :       purpose in {car,furniture/appliances,renovations}:
# :       :...savings_balance in {> 1000 DM,100 - 500 DM}: no (15.3)
# :           savings_balance = 500 - 1000 DM: yes (9.1/2.7)
# :           savings_balance in {< 100 DM,unknown}:
# :           :...dependents > 1: no (13.1/1.1)
# :               dependents <= 1:
# :               :...existing_loans_count > 2: no (5.2)
# :                   existing_loans_count <= 2:
# :                   :...percent_of_income <= 3:
# :                       :...housing in {other,rent}: yes (15.5/4.8)
# :                       :   housing = own: no (24.2/8.9)
# :                       percent_of_income > 3:
# :                       :...amount <= 4057: no (45.8/6.1)
# :                           amount > 4057: yes (13.9/5.2)
# credit_history = good:
# :...employment_duration = unemployed:
#     :...years_at_residence <= 1: yes (4)
#     :   years_at_residence > 1:
#     :   :...age <= 39: yes (17.8/7.9)
#     :       age > 39: no (5.9)
#     employment_duration = > 7 years:
#     :...dependents > 1:
#     :   :...phone = no: yes (18.8/4.6)
#     :   :   phone = yes: no (5.3)
#     :   dependents <= 1:
#     :   :...checking_balance = > 200 DM: no (9.2)
#     :       checking_balance = < 0 DM:
#     :       :...percent_of_income <= 2: no (2.5)
#     :       :   percent_of_income > 2: yes (21.4/6.1)
#     :       checking_balance in {1 - 200 DM,unknown}:
#     :       :...existing_loans_count <= 1: no (26/2.7)
#     :           existing_loans_count > 1: yes (11.4/4.4)
#     employment_duration = 4 - 7 years:
#     :...job in {management,unemployed,unskilled}: no (22.3/3.3)
#     :   job = skilled:
#     :   :...dependents > 1: no (12.6/2.3)
#     :       dependents <= 1:
#     :       :...checking_balance = < 0 DM: yes (13.1/2.4)
#     :           checking_balance in {> 200 DM,1 - 200 DM,
#     :                                unknown}: no (29.2/10.1)
#     employment_duration = 1 - 4 years:
#     :...existing_loans_count > 1: yes (14.3/2.8)
#     :   existing_loans_count <= 1:
#     :   :...savings_balance = > 1000 DM: no (3.2)
#     :       savings_balance in {100 - 500 DM,500 - 1000 DM}: yes (31.5/13.1)
#     :       savings_balance = unknown:
#     :       :...purpose in {business,car,car0,furniture/appliances,
#     :       :   :           renovations}: yes (24/7.1)
#     :       :   purpose = education: no (4.7)
#     :       savings_balance = < 100 DM:
#     :       :...purpose in {car0,renovations}: no (0)
#     :           purpose = education: yes (3.4)
#     :           purpose in {business,car,furniture/appliances}:
#     :           :...phone = no: no (74.5/33.5)
#     :               phone = yes:
#     :               :...percent_of_income <= 2: no (13.2)
#     :                   percent_of_income > 2: yes (16.1/6.5)
#     employment_duration = < 1 year:
#     :...savings_balance in {> 1000 DM,unknown}: no (16.6/3.8)
#         savings_balance in {100 - 500 DM,500 - 1000 DM}: yes (12.5/4.7)
#         savings_balance = < 100 DM:
#         :...purpose in {business,education}: no (10.2/4.3)
#             purpose in {car,car0,renovations}: yes (29.6/8.6)
#             purpose = furniture/appliances:
#             :...job = unemployed: yes (0)
#                 job = management: no (5.5)
#                 job in {skilled,unskilled}:
#                 :...dependents > 1: yes (3.5/0.3)
#                     dependents <= 1:
#                     :...years_at_residence <= 1: no (14.1/4)
#                         years_at_residence > 1:
#                         :...other_credit in {bank,store}: no (2.6)
#                             other_credit = none:
#                             :...amount <= 1318: no (3)
#                                 amount > 1318: yes (22.7/4.3)
#
# -----  Trial 7:  -----
#
# Decision tree:
#
# checking_balance in {> 200 DM,unknown}:
# :...employment_duration = unemployed: yes (12.3/4.7)
# :   employment_duration = > 7 years:
# :   :...amount <= 11560: no (75.2/17.1)
# :   :   amount > 11560: yes (3/0.6)
# :   employment_duration = 4 - 7 years:
# :   :...checking_balance = > 200 DM: yes (8.9/3.5)
# :   :   checking_balance = unknown: no (37.7/4.5)
# :   employment_duration = < 1 year:
# :   :...purpose in {car,car0}: no (12.4)
# :   :   purpose in {business,education,furniture/appliances,renovations}:
# :   :   :...amount > 4530: yes (15.2/1.6)
# :   :       amount <= 4530:
# :   :       :...purpose in {business,renovations}: yes (5.5)
# :   :           purpose in {education,furniture/appliances}: no (32.2/10.2)
# :   employment_duration = 1 - 4 years:
# :   :...months_loan_duration <= 7: no (11.9)
# :       months_loan_duration > 7:
# :       :...credit_history in {critical,poor,very good}: no (51.6/13.9)
# :           credit_history = perfect: yes (4.9/0.5)
# :           credit_history = good:
# :           :...percent_of_income <= 1: no (5.7)
# :               percent_of_income > 1:
# :               :...job = unemployed: no (0)
# :                   job in {management,unskilled}: yes (30.2/10.4)
# :                   job = skilled:
# :                   :...phone = yes: no (13/1.8)
# :                       phone = no:
# :                       :...years_at_residence <= 3: yes (15.2/4.3)
# :                           years_at_residence > 3: no (10.6/1.9)
# checking_balance in {< 0 DM,1 - 200 DM}:
# :...savings_balance in {> 1000 DM,500 - 1000 DM,unknown}: no (114.2/41.4)
#     savings_balance = 100 - 500 DM:
#     :...credit_history in {critical,poor}: no (17.2/3.8)
#     :   credit_history in {perfect,very good}: yes (9.9/1.3)
#     :   credit_history = good:
#     :   :...months_loan_duration <= 27: no (23.4/8.9)
#     :       months_loan_duration > 27: yes (8.4)
#     savings_balance = < 100 DM:
#     :...job = unemployed: yes (5.6/1.8)
#         job = unskilled:
#         :...months_loan_duration <= 22: no (60/19.2)
#         :   months_loan_duration > 22:
#         :   :...years_at_residence <= 3: no (10.7/4.2)
#         :       years_at_residence > 3: yes (19.9/2.6)
#         job = management:
#         :...years_at_residence <= 1: no (5.6)
#         :   years_at_residence > 1:
#         :   :...checking_balance = 1 - 200 DM: yes (27.1/8.8)
#         :       checking_balance = < 0 DM:
#         :       :...percent_of_income <= 1: yes (2.4)
#         :           percent_of_income > 1: no (26.3/5.7)
#         job = skilled:
#         :...other_credit = store: yes (7.6/0.9)
#             other_credit = bank:
#             :...years_at_residence <= 1: no (4.1/1.2)
#             :   years_at_residence > 1: yes (24.1/5)
#             other_credit = none:
#             :...credit_history in {perfect,very good}: yes (16.2/2.6)
#                 credit_history = poor: no (11.9/5.8)
#                 credit_history = critical:
#                 :...employment_duration in {< 1 year,unemployed}: no (5.5)
#                 :   employment_duration in {> 7 years,1 - 4 years,4 - 7 years}:
#                 :   :...dependents > 1: no (2.1)
#                 :       dependents <= 1:
#                 :       :...years_at_residence <= 2: yes (10.8/2)
#                 :           years_at_residence > 2: no (24.1/10.1)
#                 credit_history = good:
#                 :...purpose in {business,car0,education}: yes (13.8/2.6)
#                     purpose = renovations: no (0.7)
#                     purpose = car:
#                     :...years_at_residence <= 2: yes (10.6/1.9)
#                     :   years_at_residence > 2: no (21.7/6.7)
#                     purpose = furniture/appliances:
#                     :...phone = yes: yes (10.1/2.1)
#                         phone = no:
#                         :...employment_duration in {< 1 year,> 7 years,
#                             :                       4 - 7 years}: no (33/11.5)
#                             employment_duration = unemployed: yes (0.6)
#                             employment_duration = 1 - 4 years:
#                             :...dependents <= 1: yes (23.6/6.9)
#                                 dependents > 1: no (2.6)
#
# -----  Trial 8:  -----
#
# Decision tree:
#
# checking_balance in {> 200 DM,unknown}:
# :...other_credit = store: no (21.8/10.7)
# :   other_credit = none:
# :   :...credit_history in {critical,perfect,very good}: no (78.4/15.7)
# :   :   credit_history = good:
# :   :   :...existing_loans_count <= 1: no (122/34.1)
# :   :   :   existing_loans_count > 1: yes (20.7/8.4)
# :   :   credit_history = poor:
# :   :   :...percent_of_income <= 3: no (11.2/1.7)
# :   :       percent_of_income > 3: yes (22.2/7.4)
# :   other_credit = bank:
# :   :...age > 44: no (11.9/0.6)
# :       age <= 44:
# :       :...percent_of_income <= 1: no (5.8/1.7)
# :           percent_of_income > 1:
# :           :...housing in {other,rent}: yes (9.8/2.2)
# :               housing = own:
# :               :...savings_balance in {> 1000 DM,100 - 500 DM}: no (3.8)
# :                   savings_balance in {< 100 DM,500 - 1000 DM,unknown}:
# :                   :...purpose in {business,car,car0,education,
# :                       :           renovations}: yes (13.6)
# :                       purpose = furniture/appliances: no (15.2/5.9)
# checking_balance in {< 0 DM,1 - 200 DM}:
# :...checking_balance = < 0 DM:
#     :...savings_balance = > 1000 DM: no (4.6)
#     :   savings_balance in {< 100 DM,100 - 500 DM,500 - 1000 DM,unknown}:
#     :   :...dependents > 1:
#     :       :...credit_history = very good: no (0)
#     :       :   credit_history in {perfect,poor}: yes (5.1)
#     :       :   credit_history in {critical,good}:
#     :       :   :...years_at_residence <= 1: yes (2.6)
#     :       :       years_at_residence > 1: no (36/11)
#     :       dependents <= 1:
#     :       :...purpose in {business,car,car0,education}: yes (114/40.1)
#     :           purpose = renovations: no (1.3)
#     :           purpose = furniture/appliances:
#     :           :...savings_balance = 100 - 500 DM: yes (5.4)
#     :               savings_balance in {< 100 DM,500 - 1000 DM,unknown}:
#     :               :...months_loan_duration > 40: yes (5.8)
#     :                   months_loan_duration <= 40:
#     :                   :...years_at_residence <= 1: no (13.3/3.2)
#     :                       years_at_residence > 1:
#     :                       :...amount <= 1092: no (10.2/2.3)
#     :                           amount > 1092:
#     :                           :...age <= 24: yes (24.9/5.2)
#     :                               age > 24:
#     :                               :...percent_of_income <= 3: no (25.3/7.9)
#     :                                   percent_of_income > 3: yes (31.8/11.9)
#     checking_balance = 1 - 200 DM:
#     :...other_credit = store: yes (17.1/6.3)
#         other_credit = bank:
#         :...age <= 25: yes (12.5)
#         :   age > 25:
#         :   :...dependents > 1: yes (6.1/1.3)
#         :       dependents <= 1:
#         :       :...amount <= 9960: no (24.2/5.5)
#         :           amount > 9960: yes (6.8/1)
#         other_credit = none:
#         :...credit_history in {perfect,very good}: yes (17.4/5.1)
#             credit_history = poor: no (22.2/6.1)
#             credit_history = critical:
#             :...years_at_residence > 3: no (8.1)
#             :   years_at_residence <= 3:
#             :   :...months_loan_duration <= 24: no (18.7/4.9)
#             :       months_loan_duration > 24: yes (10)
#             credit_history = good:
#             :...amount > 8471: yes (9.8)
#                 amount <= 8471:
#                 :...months_loan_duration <= 8: no (10.3)
#                     months_loan_duration > 8:
#                     :...purpose in {car0,education}: no (6.6)
#                         purpose in {business,car,furniture/appliances,
#                         :           renovations}:
#                         :...job in {management,unemployed,
#                             :       unskilled}: no (36.9/12.8)
#                             job = skilled:
#                             :...housing = other: no (2.4/1)
#                                 housing = rent: yes (18.9/4.2)
#                                 housing = own:
#                                 :...dependents > 1: yes (8/1.7)
#                                     dependents <= 1:
#                                     :...months_loan_duration > 39: yes (4.9)
#                                         months_loan_duration <= 39:
#                                         :...amount <= 1056: yes (9.2/1.1)
#                                             amount > 1056: no (30.3/6.3)
#
# -----  Trial 9:  -----
#
# Decision tree:
#
# checking_balance = unknown:
# :...amount <= 1804: no (78.5/6.5)
# :   amount > 1804:
# :   :...other_credit = none: no (110.7/34)
# :       other_credit in {bank,store}:
# :       :...purpose in {car0,renovations}: yes (0)
# :           purpose = furniture/appliances: no (10.9/1.7)
# :           purpose in {business,car,education}:
# :           :...percent_of_income <= 1: no (6.7/2.5)
# :               percent_of_income > 1:
# :               :...savings_balance in {< 100 DM,> 1000 DM,100 - 500 DM,
# :                   :                   500 - 1000 DM}: yes (26/2.1)
# :                   savings_balance = unknown: no (6.6/2.2)
# checking_balance in {< 0 DM,> 200 DM,1 - 200 DM}:
# :...savings_balance = > 1000 DM: no (19.8/9.4)
#     savings_balance = 100 - 500 DM:
#     :...existing_loans_count > 3: yes (5.3)
#     :   existing_loans_count <= 3:
#     :   :...credit_history in {critical,perfect,poor}: no (19.2/4.1)
#     :       credit_history in {good,very good}: yes (39.9/12.2)
#     savings_balance = 500 - 1000 DM:
#     :...other_credit in {bank,store}: no (3.9)
#     :   other_credit = none:
#     :   :...percent_of_income <= 3: no (15.7/3.6)
#     :       percent_of_income > 3: yes (9.2/1.4)
#     savings_balance = unknown:
#     :...existing_loans_count > 1: no (21.5/1.2)
#     :   existing_loans_count <= 1:
#     :   :...job = unskilled: no (6.1)
#     :       job in {management,skilled,unemployed}:
#     :       :...months_loan_duration > 45: no (5.4)
#     :           months_loan_duration <= 45:
#     :           :...checking_balance = < 0 DM: yes (26/7.8)
#     :               checking_balance = > 200 DM: no (1.4)
#     :               checking_balance = 1 - 200 DM:
#     :               :...phone = no: no (13.9/4.2)
#     :                   phone = yes: yes (12/2.5)
#     savings_balance = < 100 DM:
#     :...age > 60: no (22.4/3.5)
#         age <= 60:
#         :...months_loan_duration <= 15:
#             :...existing_loans_count > 1:
#             :   :...amount > 4370: yes (2.9)
#             :   :   amount <= 4370:
#             :   :   :...years_at_residence > 3: no (12.8)
#             :   :       years_at_residence <= 3:
#             :   :       :...employment_duration in {< 1 year,1 - 4 years,
#             :   :           :                       4 - 7 years,
#             :   :           :                       unemployed}: no (21.8/3.1)
#             :   :           employment_duration = > 7 years: yes (5.8/0.9)
#             :   existing_loans_count <= 1:
#             :   :...housing = other: yes (10.4/2.3)
#             :       housing in {own,rent}:
#             :       :...amount > 1372: no (53.9/13.4)
#             :           amount <= 1372:
#             :           :...phone = yes: no (6.2/1.9)
#             :               phone = no:
#             :               :...credit_history = perfect: yes (0)
#             :                   credit_history in {critical,poor,
#             :                   :                  very good}: no (7.8/1.9)
#             :                   credit_history = good:
#             :                   :...dependents > 1: yes (6.5/0.6)
#             :                       dependents <= 1:
#             :                       :...months_loan_duration <= 13: yes (45.3/14.7)
#             :                           months_loan_duration > 13: no (2.8)
#             months_loan_duration > 15:
#             :...percent_of_income <= 1:
#                 :...existing_loans_count > 2: yes (3)
#                 :   existing_loans_count <= 2:
#                 :   :...amount <= 2186: yes (3.3)
#                 :       amount > 2186: no (26.1/5.7)
#                 percent_of_income > 1:
#                 :...job = management:
#                     :...credit_history in {critical,good,perfect,
#                     :   :                  very good}: no (30.8/8.5)
#                     :   credit_history = poor: yes (5.2)
#                     job in {skilled,unemployed,unskilled}:
#                     :...purpose in {business,car0}: no (23.7/9.8)
#                         purpose in {car,education,renovations}: yes (62.2/14.2)
#                         purpose = furniture/appliances:
#                         :...credit_history in {poor,very good}: yes (9)
#                             credit_history in {critical,good,perfect}:
#                             :...dependents > 1: yes (11.7/2)
#                                 dependents <= 1: [S1]
#
# SubTree [S1]
#
# employment_duration = > 7 years: no (8.7)
# employment_duration in {< 1 year,1 - 4 years,4 - 7 years,unemployed}:
# :...existing_loans_count > 1: yes (10/2.1)
#     existing_loans_count <= 1:
#     :...age <= 28: no (28.7/10.4)
#         age > 28: yes (24.1/1.3)
#
#
# Evaluation on training data (900 cases):
#
# Trial	    Decision Tree
# -----	  ----------------
# 	  Size      Errors
#
#    0	    52  130(14.4%)
#    1	    41  212(23.6%)
#    2	    39  202(22.4%)
#    3	    38  196(21.8%)
#    4	    45  200(22.2%)
#    5	    39  187(20.8%)
#    6	    61  229(25.4%)
#    7	    48  194(21.6%)
#    8	    45  174(19.3%)
#    9	    45  165(18.3%)
# boost	         46( 5.1%)   <<
#
#
# 	   (a)   (b)    <-classified as
# 	  ----  ----
# 	   630     3    (a): class no
# 	    43   224    (b): class yes
#
#
# 	Attribute usage:
#
# 	100.00%	checking_balance
# 	100.00%	credit_history
# 	 97.56%	employment_duration
# 	 97.22%	other_credit
# 	 93.56%	amount
# 	 91.33%	age
# 	 90.89%	savings_balance
# 	 87.89%	purpose
# 	 86.67%	percent_of_income
# 	 81.67%	years_at_residence
# 	 81.00%	months_loan_duration
# 	 79.33%	existing_loans_count
# 	 79.00%	dependents
# 	 78.89%	job
# 	 77.33%	housing
# 	 42.11%	phone
#
#
# Time: 0.1 secs

# %%
# Score do modelo
credit_boost_pred10 <- predict(credit_boost10, credit_test)

# Confusion Matrix
CrossTable(credit_test$default, 
           credit_boost_pred10,
           prop.chisq = FALSE, 
           prop.c = FALSE, 
           prop.r = FALSE,
           dnn = c('Observado', 'Previsto'))
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  100
#
#
#              | Previsto
#    Observado |        no |       yes | Row Total |
# -------------|-----------|-----------|-----------|
#           no |        59 |         8 |        67 |
#              |     0.590 |     0.080 |           |
# -------------|-----------|-----------|-----------|
#          yes |        16 |        17 |        33 |
#              |     0.160 |     0.170 |           |
# -------------|-----------|-----------|-----------|
# Column Total |        75 |        25 |       100 |
# -------------|-----------|-----------|-----------|

# %%
# Dando pesos aos erros

# Criando uma matriz de dimensões de custo
matrix_dimensions <- list(c("no", "yes"), c("no", "yes"))
names(matrix_dimensions) <- c("Previsto", "Observado")
matrix_dimensions
# Out:
# $Previsto
# [1] "no"  "yes"
#
# $Observado
# [1] "no"  "yes"

# %%
# Construindo a matriz
error_cost <- matrix(c(0, 1, 4, 0), nrow = 2, dimnames = matrix_dimensions)
error_cost

# Aplicando a matriz a árvore
credit_cost <- C5.0(credit_train[-17], credit_train$default, costs = error_cost)

# Score do modelo
credit_cost_pred <- predict(credit_cost, credit_test)

# Confusion Matrix
CrossTable(credit_test$default, 
           credit_cost_pred,
           prop.chisq = FALSE, 
           prop.c = FALSE, 
           prop.r = FALSE,
           dnn = c('Observado', 'Previsto'))
# Out:
#         Observado
# Previsto no yes
#      no  0  4
#      yes 1  0
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  100
#
#
#              | Previsto
#    Observado |        no |       yes | Row Total |
# -------------|-----------|-----------|-----------|
#           no |        43 |        24 |        67 |
#              |     0.430 |     0.240 |           |
# -------------|-----------|-----------|-----------|
#          yes |         7 |        26 |        33 |
#              |     0.070 |     0.260 |           |
# -------------|-----------|-----------|-----------|
# Column Total |        50 |        50 |       100 |
# -------------|-----------|-----------|-----------|
